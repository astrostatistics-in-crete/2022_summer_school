# %% [markdown]
# # Deep Learning - Workshop

# %%
import glob
import pickle
import numpy as np
from prettytable import PrettyTable
from matplotlib import pyplot as plt
import pandas as pd

# Packages for autoencoder:
from sklearn.datasets import make_regression
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LeakyReLU
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras import layers
import tensorflow as tf
from tensorflow.keras.optimizers import SGD

# Packages for Black-Body function:
from astropy.modeling.models import BlackBody
from astropy import units as u
from astropy.visualization import quantity_support

# %%
path_spectra = "/data/schools/Astrostatistics_School_Crete_2022/2022_summer_school/Deep Learning/make_spectra/spectra_noabs"

n_spectra = 10000
# number of spectra to use

# %%
# %%time
spectrum_files = glob.glob(path_spectra+'/*.pkl')

# Capping number of spectra:
spectrum_files = spectrum_files[:n_spectra]

# Creating data structure:
X = []
Y = []

for spectrum_file in spectrum_files:
    with open(spectrum_file, 'rb') as fh:
        spectrum = pickle.load(fh)

    spectrum_data     = spectrum['data']
    spectrum_metadata = spectrum['metadata']

    X.append(spectrum_data['flux_Jy'])
    Y.append(spectrum_metadata)

wave_mu = spectrum_data['wave_mu']
# the same for all spectra (using here the last spectrum)
    
X = np.array(X)
# Out:
# CPU times: user 312 ms, sys: 75.9 ms, total: 387 ms
# Wall time: 388 ms

# %% [markdown]
# ## Preparing Data

# %%
# Splitting dataset into train/validation/test sets:
X_rest, X_test, Y_rest, Y_test = train_test_split(X, Y, test_size=0.1, random_state=1)
X_train, X_valid, Y_train, Y_valid = train_test_split(X_rest, Y_rest, test_size=0.3, random_state=1)

del X_rest
# purging exploited variable to save memory

table = PrettyTable()
table.title = 'Train/valid/test data shape'
table.field_names = ['', 'X', 'y']
table.add_row(['train', np.shape(X_train), np.shape(Y_train)])
table.add_row(['valid', np.shape(X_valid), np.shape(Y_valid)])
table.add_row(['test', np.shape(X_test), np.shape(Y_test)])
print(table)
# Out:
# +-------------------------------+
# |  Train/valid/test data shape  |
# +-------+-------------+---------+
# |       |      X      |    y    |
# +-------+-------------+---------+
# | train | (6300, 100) | (6300,) |
# | valid | (2700, 100) | (2700,) |
# |  test | (1000, 100) | (1000,) |
# +-------+-------------+---------+

# %% [markdown]
# ### Normalizing data

# %%
# Normalizing data:
norm = MinMaxScaler()
norm.fit(X_train)
'''
X_n_train = norm.transform(X_train)
X_n_valid = norm.transform(X_valid)
X_n_test  = norm.transform(X_test)
''';
X_n_train = X_train.copy()
X_n_valid = X_valid.copy()
X_n_test  = X_test.copy()

# %%
def normalize(X):
    X_n = np.log10(X)
    return X_n

X_n_train = normalize(X_train)
X_n_valid = normalize(X_valid)
X_n_test  = normalize(X_test)

plt.plot(wave_mu, X_n_train[0])
plt.plot(wave_mu, X_n_valid[0])
plt.plot(wave_mu, X_n_test[0])
plt.xscale('log')

# %% [markdown]
# ## Autoncoder
#
# <img src="images/autoencoder.png"/>

# %%
from keras import backend as K

def BuildSpectrum(x):
        
    wave_cm = wave_mu * 1e-4 # cm
    wave_cm = tf.expand_dims(wave_cm, axis=0)

    T_star = tf.gather(x, [0], axis=-1)
    N_star = tf.gather(x, [1], axis=-1)
    T_dust = tf.gather(x, [2], axis=-1)
    N_dust = tf.gather(x, [3], axis=-1)
#    Tau = tf.gather(x, [4], axis=-1)

    # Casting type float32->float64 to increase numerical accuracy:
    # (required to properly calculate the tails of the BB)
    T_star = tf.cast(T_star, tf.float64)
    N_star = tf.cast(N_star, tf.float64)
    T_dust = tf.cast(T_dust, tf.float64)
    N_dust = tf.cast(N_dust, tf.float64)
#    Tau = tf.cast(Tau, tf.float64)

    def BB(wave_cm, T, N):
        '''
        Returns a Black Body function evaluated over the <wave_cm> array, in:
            ergs/s/cm^2/Hz/sr

        Reproduces exactly the function defined as in:
            https://docs.astropy.org/en/stable/api/astropy.modeling.physical_models.BlackBody.html
        '''

        c = 3e10 # cm/sec
        freq_Hz = c / wave_cm
        h = 6.6261e-27 # cgs
        k = 1.3807e-16 # cgs

        ones = tf.cast(tf.ones(tf.size(wave_cm)), tf.float64)
        numerator   = 2*h*tf.pow(freq_Hz,3)/c**2
        denominator = tf.math.exp(h*freq_Hz/(k*T)) - ones

        eps= 1e-20
        # small additive constant to avoid numerical issues
        
        BB = N * numerator / denominator + eps
        #tf.print(BB)
        
        return BB
        
    BB_star = BB(wave_cm, T_star, N_star)
    BB_dust = BB(wave_cm, T_dust, N_dust)

    # Converting into flux density:
    sr = 1e-10
    # steradiants to convert ergs/s/cm^2/Hz/sr -> ergs/s/cm^2/Hz
    # (this is the same arbitrary value used when the spectra were generated)
    cgs_to_Jy = 1e-23
    # conversion factor for flux from ergs/s/cm^2/Hz -> Jansky

    BB_star = BB_star * sr / cgs_to_Jy
    BB_dust = BB_dust * sr / cgs_to_Jy

#    BB_star_abs = BB_star * tf.math.exp(-Tau/(wave_cm*1e4))
    # this must me in micron

#    BB = tf.add(BB_star_abs, BB_dust)
    BB = tf.add(BB_star, BB_dust)

    # Normalization:
    BB_log10 = tf.experimental.numpy.log10(BB)
    
    return BB_log10

# %%
from keras import backend as K

def CustomActivationFunction(x) :
    # https://stackoverflow.com/questions/44553722/restricting-the-output-values-of-layers-in-keras

    #tf.print('CustomAct: x', x[0,:])

    # Scaling around 1:
    # working best: x_renorm = K.sigmoid(x)*2 + 1
    # with: learning_rate=0.001, momentum=0.9, clipvalue=0.005
    #x_renorm = K.sigmoid(x)*2 + 1
    x_renorm = x
    #tf.print('CustomAct: x_renorm', x_renorm[0,:])

    # Grabbing layer's neuron values:
    T_star = tf.gather(x_renorm, [0], axis=-1)
    N_star = tf.gather(x_renorm, [1], axis=-1)
    T_dust = tf.gather(x_renorm, [2], axis=-1)
    N_dust = tf.gather(x_renorm, [3], axis=-1)
#    Tau    = tf.gather(x_renorm, [4], axis=-1)

    # Scaling -100% to 100% around average expected values:
    T_star = K.sigmoid(T_star)*3*6000
    N_star = K.sigmoid(N_star)*2*1e-6
    T_dust = K.sigmoid(T_dust)*2*500 + 50
    N_dust = K.sigmoid(N_dust)*2*1e0
#    Tau    = K.sigmoid(Tau)*1
    
#    x_activated = K.concatenate([T_star,N_star,T_dust,N_dust,Tau], axis=-1)
    x_activated = K.concatenate([T_star,N_star,T_dust,N_dust], axis=-1)

    #tf.print('CustomAct: x_act', x_activated[0,:])
    
    return x_activated

# %%
# Autoencoder: 
#     https://stackabuse.com/autoencoders-for-image-reconstruction-in-python-and-keras/
# Lambda layer:
#     https://keras.io/api/layers/core_layers/lambda/

# Batch normalization - theory:
#    https://datascience.stackexchange.com/questions/53426/what-exactly-is-batchnormalization-in-keras
# application:
#    https://stackoverflow.com/questions/34716454/where-do-i-call-the-batchnormalization-function-in-keras

from tensorflow.keras.layers import Dense, Input, InputLayer, Lambda, Activation
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras import activations

n_inputs = X.shape[1]
n_latent = 4

def build_autoencoder(n_inputs, n_latent):
    # The encoder
    encoder = Sequential()
    encoder.add(InputLayer(n_inputs))
    #
    encoder.add(Dense(n_inputs))
    encoder.add(BatchNormalization())
    encoder.add(Activation('relu'))
    encoder.add(Dense(n_inputs/2))
    encoder.add(BatchNormalization())
    encoder.add(Activation('relu'))
    encoder.add(Dense(n_inputs/4))
    encoder.add(BatchNormalization())
    encoder.add(Activation('sigmoid'))
    encoder.add(Dense(n_latent, activation=CustomActivationFunction))

    # The decoder
    decoder = Sequential()
    decoder.add(InputLayer((n_latent,)))
    #
    decoder.add(Lambda(BuildSpectrum))

    decoder.layers[-1].trainable = False
    # not necessary, just here for redundancy
    
    return encoder, decoder

encoder, decoder = build_autoencoder(n_inputs, n_latent)

print(encoder.summary())
print(decoder.summary())
# Non-informative, in this case:
# print(model.summary())

#decoder.layers[-1].set_weights([[5000,1e-7,250,10],0])
#print('--', decoder.layers[-1].get_weights())

inp = Input(n_inputs)
encoded = encoder(inp)
reconstruction = decoder(encoded)

model = Model(inp, reconstruction)

# Compiling autoencoder model:
opt = SGD(learning_rate=0.01, momentum=0.9)#, clipvalue=0.5)
model.compile(optimizer=opt, run_eagerly=False, loss='mae')
# NOTE: run_eagerly=True allows to convert tensors to numpys
#       (useful for testing but less efficient)
#K.set_value(model.optimizer.learning_rate, 0.0001)
# default Keras learning rate = 0.001

weights_init = model.get_weights()
# saving initialization weights
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_9 (Dense)             (None, 100)               10100
#
#  batch_normalization_6 (Batc  (None, 100)              400
#  hNormalization)
#
#  activation_6 (Activation)   (None, 100)               0
#
#  dense_10 (Dense)            (None, 50)                5050
#
#  batch_normalization_7 (Batc  (None, 50)               200
#  hNormalization)
#
#  activation_7 (Activation)   (None, 50)                0
#
#  dense_11 (Dense)            (None, 4)                 204
#
# =================================================================
# Total params: 15,954
# Trainable params: 15,654
# Non-trainable params: 300
# _________________________________________________________________
# None
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lambda_3 (Lambda)           (None, 100)               0
#
# =================================================================
# Total params: 0
# Trainable params: 0
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
# %%time
model.set_weights(weights_init)
# restoring initialized weights to have a fresh, identical fit very time model.fit() is run

# fit the autoencoder model to reconstruct input
history = model.fit(X_n_train, X_n_train, epochs=100, batch_size=512, verbose=2,
                    validation_data=(X_n_valid,X_n_valid), shuffle=False)
# plot loss
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='valid')
plt.legend()
plt.show()
# Out:
# Epoch 1/100
# 13/13 - 1s - loss: 0.5428 - val_loss: 0.6618 - 1s/epoch - 107ms/step
# Epoch 2/100
# 13/13 - 0s - loss: 0.2698 - val_loss: 0.3998 - 87ms/epoch - 7ms/step
# Epoch 3/100
# 13/13 - 0s - loss: 0.2096 - val_loss: 0.4277 - 90ms/epoch - 7ms/step
# Epoch 4/100
# 13/13 - 0s - loss: 0.1665 - val_loss: 0.3952 - 92ms/epoch - 7ms/step
# Epoch 5/100
# 13/13 - 0s - loss: 0.1575 - val_loss: 0.3653 - 92ms/epoch - 7ms/step
# Epoch 6/100
# 13/13 - 0s - loss: 0.1553 - val_loss: 0.3459 - 89ms/epoch - 7ms/step
# Epoch 7/100
# 13/13 - 0s - loss: 0.1497 - val_loss: 0.3236 - 89ms/epoch - 7ms/step
# Epoch 8/100
# 13/13 - 0s - loss: 0.1445 - val_loss: 0.3135 - 91ms/epoch - 7ms/step
# Epoch 9/100
# 13/13 - 0s - loss: 0.1432 - val_loss: 0.3036 - 96ms/epoch - 7ms/step
# Epoch 10/100
# 13/13 - 0s - loss: 0.1412 - val_loss: 0.2959 - 105ms/epoch - 8ms/step
# Epoch 11/100
# 13/13 - 0s - loss: 0.1404 - val_loss: 0.2897 - 90ms/epoch - 7ms/step
# Epoch 12/100
# 13/13 - 0s - loss: 0.1390 - val_loss: 0.2823 - 98ms/epoch - 8ms/step
# Epoch 13/100
# 13/13 - 0s - loss: 0.1390 - val_loss: 0.2772 - 94ms/epoch - 7ms/step
# Epoch 14/100
# 13/13 - 0s - loss: 0.1375 - val_loss: 0.2671 - 92ms/epoch - 7ms/step
# Epoch 15/100
# 13/13 - 0s - loss: 0.1387 - val_loss: 0.2665 - 92ms/epoch - 7ms/step
# Epoch 16/100
# 13/13 - 0s - loss: 0.1364 - val_loss: 0.2499 - 94ms/epoch - 7ms/step
# Epoch 17/100
# 13/13 - 0s - loss: 0.1394 - val_loss: 0.2573 - 91ms/epoch - 7ms/step
# Epoch 18/100
# 13/13 - 0s - loss: 0.1365 - val_loss: 0.2337 - 90ms/epoch - 7ms/step
# Epoch 19/100
# 13/13 - 0s - loss: 0.1396 - val_loss: 0.2424 - 94ms/epoch - 7ms/step
# Epoch 20/100
# 13/13 - 0s - loss: 0.1367 - val_loss: 0.2173 - 88ms/epoch - 7ms/step
# Epoch 21/100
# 13/13 - 0s - loss: 0.1387 - val_loss: 0.2240 - 96ms/epoch - 7ms/step
# Epoch 22/100
# 13/13 - 0s - loss: 0.1356 - val_loss: 0.2029 - 93ms/epoch - 7ms/step
# Epoch 23/100
# 13/13 - 0s - loss: 0.1387 - val_loss: 0.2084 - 91ms/epoch - 7ms/step
# Epoch 24/100
# 13/13 - 0s - loss: 0.1354 - val_loss: 0.1906 - 91ms/epoch - 7ms/step
# Epoch 25/100
# 13/13 - 0s - loss: 0.1384 - val_loss: 0.1942 - 90ms/epoch - 7ms/step
# Epoch 26/100
# 13/13 - 0s - loss: 0.1351 - val_loss: 0.1801 - 94ms/epoch - 7ms/step
# Epoch 27/100
# 13/13 - 0s - loss: 0.1380 - val_loss: 0.1816 - 89ms/epoch - 7ms/step
# Epoch 28/100
# 13/13 - 0s - loss: 0.1347 - val_loss: 0.1717 - 89ms/epoch - 7ms/step
# Epoch 29/100
# 13/13 - 0s - loss: 0.1378 - val_loss: 0.1715 - 89ms/epoch - 7ms/step
# Epoch 30/100
# 13/13 - 0s - loss: 0.1346 - val_loss: 0.1643 - 90ms/epoch - 7ms/step
# Epoch 31/100
# 13/13 - 0s - loss: 0.1374 - val_loss: 0.1627 - 89ms/epoch - 7ms/step
# Epoch 32/100
# 13/13 - 0s - loss: 0.1341 - val_loss: 0.1590 - 87ms/epoch - 7ms/step
# Epoch 33/100
# 13/13 - 0s - loss: 0.1374 - val_loss: 0.1571 - 89ms/epoch - 7ms/step
# Epoch 34/100
# 13/13 - 0s - loss: 0.1341 - val_loss: 0.1548 - 90ms/epoch - 7ms/step
# Epoch 35/100
# 13/13 - 0s - loss: 0.1372 - val_loss: 0.1526 - 87ms/epoch - 7ms/step
# Epoch 36/100
# 13/13 - 0s - loss: 0.1339 - val_loss: 0.1518 - 89ms/epoch - 7ms/step
# Epoch 37/100
# 13/13 - 0s - loss: 0.1370 - val_loss: 0.1493 - 88ms/epoch - 7ms/step
# Epoch 38/100
# 13/13 - 0s - loss: 0.1338 - val_loss: 0.1494 - 93ms/epoch - 7ms/step
# Epoch 39/100
# 13/13 - 0s - loss: 0.1368 - val_loss: 0.1462 - 103ms/epoch - 8ms/step
# Epoch 40/100
# 13/13 - 0s - loss: 0.1335 - val_loss: 0.1474 - 103ms/epoch - 8ms/step
# Epoch 41/100
# 13/13 - 0s - loss: 0.1367 - val_loss: 0.1443 - 98ms/epoch - 8ms/step
# Epoch 42/100
# 13/13 - 0s - loss: 0.1334 - val_loss: 0.1461 - 89ms/epoch - 7ms/step
# Epoch 43/100
# 13/13 - 0s - loss: 0.1365 - val_loss: 0.1425 - 92ms/epoch - 7ms/step
# Epoch 44/100
# 13/13 - 0s - loss: 0.1330 - val_loss: 0.1456 - 93ms/epoch - 7ms/step
# Epoch 45/100
# 13/13 - 0s - loss: 0.1366 - val_loss: 0.1422 - 97ms/epoch - 7ms/step
# Epoch 46/100
# 13/13 - 0s - loss: 0.1333 - val_loss: 0.1451 - 97ms/epoch - 7ms/step
# Epoch 47/100
# 13/13 - 0s - loss: 0.1362 - val_loss: 0.1399 - 106ms/epoch - 8ms/step
# Epoch 48/100
# 13/13 - 0s - loss: 0.1326 - val_loss: 0.1443 - 107ms/epoch - 8ms/step
# Epoch 49/100
# 13/13 - 0s - loss: 0.1362 - val_loss: 0.1399 - 97ms/epoch - 7ms/step
# Epoch 50/100
# 13/13 - 0s - loss: 0.1327 - val_loss: 0.1444 - 93ms/epoch - 7ms/step
# Epoch 51/100
# 13/13 - 0s - loss: 0.1360 - val_loss: 0.1393 - 100ms/epoch - 8ms/step
# Epoch 52/100
# 13/13 - 0s - loss: 0.1326 - val_loss: 0.1441 - 95ms/epoch - 7ms/step
# Epoch 53/100
# 13/13 - 0s - loss: 0.1357 - val_loss: 0.1375 - 94ms/epoch - 7ms/step
# Epoch 54/100
# 13/13 - 0s - loss: 0.1318 - val_loss: 0.1436 - 97ms/epoch - 7ms/step
# Epoch 55/100
# 13/13 - 0s - loss: 0.1361 - val_loss: 0.1396 - 97ms/epoch - 7ms/step
# Epoch 56/100
# 13/13 - 0s - loss: 0.1329 - val_loss: 0.1438 - 95ms/epoch - 7ms/step
# Epoch 57/100
# 13/13 - 0s - loss: 0.1351 - val_loss: 0.1362 - 91ms/epoch - 7ms/step
# Epoch 58/100
# 13/13 - 0s - loss: 0.1312 - val_loss: 0.1426 - 96ms/epoch - 7ms/step
# Epoch 59/100
# 13/13 - 0s - loss: 0.1359 - val_loss: 0.1389 - 95ms/epoch - 7ms/step
# Epoch 60/100
# 13/13 - 0s - loss: 0.1325 - val_loss: 0.1437 - 95ms/epoch - 7ms/step
# Epoch 61/100
# 13/13 - 0s - loss: 0.1350 - val_loss: 0.1364 - 88ms/epoch - 7ms/step
# Epoch 62/100
# 13/13 - 0s - loss: 0.1311 - val_loss: 0.1429 - 90ms/epoch - 7ms/step
# Epoch 63/100
# 13/13 - 0s - loss: 0.1355 - val_loss: 0.1384 - 97ms/epoch - 7ms/step
# Epoch 64/100
# 13/13 - 0s - loss: 0.1321 - val_loss: 0.1440 - 100ms/epoch - 8ms/step
# Epoch 65/100
# 13/13 - 0s - loss: 0.1349 - val_loss: 0.1368 - 101ms/epoch - 8ms/step
# Epoch 66/100
# 13/13 - 0s - loss: 0.1311 - val_loss: 0.1430 - 91ms/epoch - 7ms/step
# Epoch 67/100
# 13/13 - 0s - loss: 0.1352 - val_loss: 0.1379 - 93ms/epoch - 7ms/step
# Epoch 68/100
# 13/13 - 0s - loss: 0.1315 - val_loss: 0.1438 - 94ms/epoch - 7ms/step
# Epoch 69/100
# 13/13 - 0s - loss: 0.1349 - val_loss: 0.1379 - 93ms/epoch - 7ms/step
# Epoch 70/100
# 13/13 - 0s - loss: 0.1315 - val_loss: 0.1438 - 93ms/epoch - 7ms/step
# Epoch 71/100
# 13/13 - 0s - loss: 0.1345 - val_loss: 0.1365 - 96ms/epoch - 7ms/step
# Epoch 72/100
# 13/13 - 0s - loss: 0.1306 - val_loss: 0.1425 - 91ms/epoch - 7ms/step
# Epoch 73/100
# 13/13 - 0s - loss: 0.1349 - val_loss: 0.1381 - 96ms/epoch - 7ms/step
# Epoch 74/100
# 13/13 - 0s - loss: 0.1312 - val_loss: 0.1433 - 97ms/epoch - 7ms/step
# Epoch 75/100
# 13/13 - 0s - loss: 0.1344 - val_loss: 0.1367 - 93ms/epoch - 7ms/step
# Epoch 76/100
# 13/13 - 0s - loss: 0.1304 - val_loss: 0.1424 - 94ms/epoch - 7ms/step
# Epoch 77/100
# 13/13 - 0s - loss: 0.1346 - val_loss: 0.1376 - 97ms/epoch - 7ms/step
# Epoch 78/100
# 13/13 - 0s - loss: 0.1306 - val_loss: 0.1429 - 95ms/epoch - 7ms/step
# Epoch 79/100
# 13/13 - 0s - loss: 0.1344 - val_loss: 0.1374 - 93ms/epoch - 7ms/step
# Epoch 80/100
# 13/13 - 0s - loss: 0.1304 - val_loss: 0.1425 - 94ms/epoch - 7ms/step
# Epoch 81/100
# 13/13 - 0s - loss: 0.1343 - val_loss: 0.1372 - 97ms/epoch - 7ms/step
# Epoch 82/100
# 13/13 - 0s - loss: 0.1302 - val_loss: 0.1419 - 93ms/epoch - 7ms/step
# Epoch 83/100
# 13/13 - 0s - loss: 0.1343 - val_loss: 0.1370 - 98ms/epoch - 8ms/step
# Epoch 84/100
# 13/13 - 0s - loss: 0.1299 - val_loss: 0.1411 - 94ms/epoch - 7ms/step
# Epoch 85/100
# 13/13 - 0s - loss: 0.1343 - val_loss: 0.1368 - 97ms/epoch - 7ms/step
# Epoch 86/100
# 13/13 - 0s - loss: 0.1298 - val_loss: 0.1412 - 100ms/epoch - 8ms/step
# Epoch 87/100
# 13/13 - 0s - loss: 0.1343 - val_loss: 0.1370 - 102ms/epoch - 8ms/step
# Epoch 88/100
# 13/13 - 0s - loss: 0.1297 - val_loss: 0.1406 - 94ms/epoch - 7ms/step
# Epoch 89/100
# 13/13 - 0s - loss: 0.1342 - val_loss: 0.1367 - 105ms/epoch - 8ms/step
# Epoch 90/100
# 13/13 - 0s - loss: 0.1295 - val_loss: 0.1401 - 96ms/epoch - 7ms/step
# Epoch 91/100
# 13/13 - 0s - loss: 0.1342 - val_loss: 0.1374 - 93ms/epoch - 7ms/step
# Epoch 92/100
# 13/13 - 0s - loss: 0.1298 - val_loss: 0.1413 - 98ms/epoch - 8ms/step
# Epoch 93/100
# 13/13 - 0s - loss: 0.1338 - val_loss: 0.1364 - 97ms/epoch - 7ms/step
# Epoch 94/100
# 13/13 - 0s - loss: 0.1293 - val_loss: 0.1402 - 97ms/epoch - 7ms/step
# Epoch 95/100
# 13/13 - 0s - loss: 0.1341 - val_loss: 0.1372 - 96ms/epoch - 7ms/step
# Epoch 96/100
# 13/13 - 0s - loss: 0.1294 - val_loss: 0.1400 - 96ms/epoch - 7ms/step
# Epoch 97/100
# 13/13 - 0s - loss: 0.1340 - val_loss: 0.1373 - 96ms/epoch - 7ms/step
# Epoch 98/100
# 13/13 - 0s - loss: 0.1295 - val_loss: 0.1408 - 96ms/epoch - 7ms/step
# Epoch 99/100
# 13/13 - 0s - loss: 0.1336 - val_loss: 0.1363 - 96ms/epoch - 7ms/step
# Epoch 100/100
# 13/13 - 0s - loss: 0.1289 - val_loss: 0.1398 - 99ms/epoch - 8ms/step
# CPU times: user 30.2 s, sys: 1.88 s, total: 32 s
# Wall time: 11 s

# %% [markdown]
# ## Assessment

# %% [markdown]
# ### Predicting

# %%
# Predict spectrum (full model):
X_n_test_pred = model.predict(X_n_test)
# Predict parameters (encoder only):
y_test_pred = encoder.predict(X_n_test)

# %% [markdown]
# ### Comparing: prediction _vs_ true

# %%
# Plotting a few test examples:
import random

fig, axes = plt.subplots(2,2, figsize=(8,6))
axes = axes.flatten()

for i, ax in enumerate(axes):

    j = random.randint(0, len(X_n_test))

    ax.plot(wave_mu, X_n_test[j], label='original')
    ax.plot(wave_mu, X_n_test_pred[j], label='model')
    ax.set_xscale('log')
    ax.legend()

# %%
y_test = np.array([np.fromiter(params.values(), dtype=float) for params in Y_test])
# converting dictionary to np.array

y_params = list(Y_test[0].keys())
# parameter names: the same for all spectra (using the first)

fig, axes = plt.subplots(2,2, figsize=(8,6))
axes = axes.flatten()

for i, ax in enumerate(axes):
# i = parameter index

    if i+1 > len(y_params):
    # to delete extra panels in case we plot more than 4 parameters
        fig.delaxes(ax)

    min_ax, max_ax = np.min(y_test[:,i]), np.max(y_test[:,i])
    # 1-to-1 line:
    xx = np.linspace(min_ax, max_ax, 100)
    ax.plot(xx, xx, c="grey", linestyle='--')

    ax.scatter(y_test[:,i], y_test_pred[:,i])
    ax.set_title(y_params[i])
    ax.set_xlabel('true')
    ax.set_ylabel('predicted')
    ax.set_xlim([min_ax, max_ax])
    #ax.set_ylim([min_ax, max_ax])

    #ax.set_aspect('equal', 'box')

fig.tight_layout()
plt.show()

# %%
###EOF
